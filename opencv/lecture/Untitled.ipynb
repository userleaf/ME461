# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io
import skimage

# %%
homer = io.imread("./homer-simpson-medium.jpg")

# %%
plt.imshow(homer)

# %% [raw]
# r=homer[:,:,0]
# g=homer[:,:,1]
# b=homer[:,:,2]

# %%
r=homer[:,:,0]
g=homer[:,:,1]
b=homer[:,:,2]

# %%
io.imshow(homer)

# %%
mask=np.zeros([homer.shape[0],homer.shape[1]])
for j in range(homer.shape[0]-1):
    for i in range(homer.shape[1]-1):
        if homer[j][i][0]!=0 and homer[j][i][1]!=0 and homer[j][i][2]/((homer[j][i][0]+homer[j][i][1])/2)<0.02:
            mask[j][i]=1
io.imshow(mask)
# Out:
# /tmp/ipykernel_10521/4000062880.py:4: RuntimeWarning: overflow encountered in ubyte_scalars
#   if homer[j][i][0]!=0 and homer[j][i][1]!=0 and homer[j][i][2]/((homer[j][i][0]+homer[j][i][1])/2)<0.02:
# /tmp/ipykernel_10521/4000062880.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   if homer[j][i][0]!=0 and homer[j][i][1]!=0 and homer[j][i][2]/((homer[j][i][0]+homer[j][i][1])/2)<0.02:
# /tmp/ipykernel_10521/4000062880.py:4: RuntimeWarning: invalid value encountered in true_divide
#   if homer[j][i][0]!=0 and homer[j][i][1]!=0 and homer[j][i][2]/((homer[j][i][0]+homer[j][i][1])/2)<0.02:
